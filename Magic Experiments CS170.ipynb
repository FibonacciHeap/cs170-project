# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %run run_input_experiment.py
# Out:
# 2017-11-10 18:36:11,988 Experiment: n = 5, starting k = 1
# 2017-11-10 18:36:11,990 Trying k = 1
# Iteration 421/1000
# 2017-11-10 18:36:12,270 Trying k = 2
# Iteration 321/1000
# 2017-11-10 18:36:12,589 Trying k = 3
# Iteration 479/1000
# 2017-11-10 18:36:12,879 Trying k = 4
# Iteration 351/1000
# 2017-11-10 18:36:13,184 Trying k = 5
# Iteration 311/1000
# 2017-11-10 18:36:13,490 Trying k = 6
# Iteration 65/1000
# 2017-11-10 18:36:13,787 Trying k = 7
# Iteration 72/1000
# 2017-11-10 18:36:14,105 Trying k = 8
# Iteration 69/1000
# 2017-11-10 18:36:14,431 Trying k = 9
# Iteration 70/1000
# 2017-11-10 18:36:14,759 Trying k = 10
# Iteration 135/1000
# 2017-11-10 18:36:15,105 Trying k = 11
# Iteration 60/1000
# 2017-11-10 18:36:15,446 Trying k = 12
# Iteration 25/1000
# 2017-11-10 18:36:15,789 Trying k = 13
# Iteration 67/1000
# 2017-11-10 18:36:16,144 Trying k = 14
# Iteration 311/1000
# 2017-11-10 18:36:16,589 Trying k = 15
# Iteration 26/1000
# Iteration 200/1000
# ...

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %run run_input_experiment.py
# Out:
# 2017-11-10 23:49:58,727 Experiment: n = 6, starting k = 2
# 2017-11-10 23:49:58,729 Trying k = 2
# Running experiment for RANDOM Constraint Strategy.
# Iteration 189/1000
# 2017-11-10 23:50:00,051 Trying k = 3
# Iteration 48/1000
# Iteration 179/1000
# 2017-11-10 23:50:01,498 Trying k = 4
# Iteration 40/1000
# Iteration 165/1000
# 2017-11-10 23:50:03,079 Trying k = 5
# Iteration 87/1000
# Iteration 618/1000
# 2017-11-10 23:50:04,833 Trying k = 6
# Iteration 183/10000
# 2017-11-10 23:50:06,491 Trying k = 7
# Iteration 1000/1000
# Iteration 183/1000
# 2017-11-10 23:50:08,243 Trying k = 8
# Iteration 19/1000
# Iteration 338/1000
# 2017-11-10 23:50:10,035 Trying k = 9
# Iteration 31/1000
# Iteration 752/1000
# 2017-11-10 23:50:11,803 Trying k = 10
# Iteration 454/10000
# 2017-11-10 23:50:13,617 Trying k = 11
# Iteration 34/1000
# Iteration 467/1000
# 2017-11-10 23:50:15,401 Trying k = 12
# Iteration 55/1000
# Iteration 389/1000
# 2017-11-10 23:50:17,156 Trying k = 13
# Iteration 56/1000
# ...
